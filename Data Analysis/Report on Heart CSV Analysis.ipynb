# %% [markdown]
# # Introduction

# %% [markdown]
# Heart diseases are a significant health concern globally. This report analyzes a dataset focusing on heart health, consisting of various factors such as age, sex, blood pressure, cholesterol levels, and more. The aim is to uncover insights that can aid in understanding and managing health.
#
# The dataset includes columns or features like age, sex, chest pain type, blood pressure, cholesterol levels, and others, along with a target variable indicating the presence of heart disease.
#
# Through data analysis techniques and data visualization, this report aims to identify patterns, correlations, and potential risk factors associated with heart disease. The findings can be helpful to the treatment stratigies of the heart disease patients which also can be helfpful to prevent the risk of heart failure.

# %% [markdown]
# # Data Loading

# %%
#importing libraries 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading heart csv file using pandas
df = pd.read_csv('heart.csv')  # assgined all the data into df named vairable which will work as dataframe

# %%
print('Printing the data of csv file')
df
# Out:
# Printing the data of csv file
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# ...

# %%
print('Displaying the 5 rows of dataset which is on top.')
df.head(5) #head function prints top rows of dataset you can also assign numbers as many number of rows you want
# Out:
# Displaying the 5 rows of dataset which is on top.
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
print('Displaying the 5 rows of dataset which is on bottom.')
df.tail(5) #tail function prints bottom rows of dataset, you can also assign numbers as many number of rows you want
# Out:
# Displaying the 5 rows of dataset which is on bottom.
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %% [markdown]
# ## Data Description of columns
# 1. age
# 2. sex
# 3. cp: chest pain type (4 values)
#         Value 0: typical angina
#         Value 1: atypical angina
#         Value 2: non-angina pain
#         Value 3: asymptomatic
# 4. trestbps: resting blood pressure(in mm Hg on admission to the hospital
# 5. chol: serum cholestoral in mg/dl
# 6. fbs: fasting blood sugar > 120 mg/dl(1=true; 0=false)
# 7. restecg: resting electrocardiographic results (values 0,1,2)
#         Value 0: normal
#         Value 1: having ST-T wave abnormality (T-wave inversions and/or ST elevation or depression of>0.05 mV)
#         Value 2: Showing probable or definite left ventricular hypertrophy by Estes criteria
# 8. thalach: maximum heart rate achieved
# 9. exang: exercise induced angina
# 10. oldpeak: oldpeak = ST depression induced by exercise relative to rest
# 11. slope: the slope of the peak exercise ST segment
#         value 1: upsloping
#         value 2: flat
#         value 3: downsloping
# 12. ca: number of major vessels (0-3) colored by flourosopy
# 13. thal:
#         0 = normal
#         1 = fixed defect
#         2 = reversable defect
# 14. target:
#         0 = less chance of heart attack
#         1 = more chance of heart attack

# %%
print('The shape of whole dataset is: ')
data_shape = df.shape
data_shape
# Out:
# The shape of whole dataset is:
# (1025, 14)

# %%
print('Number of rows in dataset is ', data_shape[0])
print('Number of columns in dataset is',data_shape[1])
# Out:
# Number of rows in dataset is  1025
# Number of columns in dataset is 14

# %%
inf = df.info()
print('Display above is all information regarding the dataset like (dtypes, memory usage, Non-Null Count) ')
inf
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB
# Display above is all information regarding the dataset like (dtypes, memory usage, Non-Null Count)

# %%
describe = df.describe(include ='all') #include all includes all columns contained (int,str,float) values
print('Displaying all the description of statistical data of dataset including float, integer and string : ')
describe
# Out:
# Displaying all the description of statistical data of dataset including float, integer and string :
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# ...

# %%
dtype = df.dtypes
print("Displying all the data types of columns: ")
dtype
# Out:
# Displying all the data types of columns:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %% [markdown]
# # Data Preprocessing
#
# Data preprocessing is an essential step in the data analysis ,where we transform , clean and organize the raw data to ensure the quality and usability of dataset for further analysis and visualization.

# %% [markdown]
# ## 1. Data Cleaning
# In data cleaning step we identify the null values , empty cells , duplicate values then we do use strategy like fill , replace or delete the row or columns as per the need respectively to ensure the quality of dataset. Therefore we can ensure that there wont't be any issues or errors regarding data.

# %%
#lets check if there is null value or not in the dataset
df.isnull().any()
# Out:
# age         False
# sex         False
# cp          False
# trestbps    False
# chol        False
# fbs         False
# restecg     False
# thalach     False
# exang       False
# oldpeak     False
# slope       False
# ca          False
# thal        False
# target      False
# dtype: bool

# %% [markdown]
# As we can see above all the columns giving false output that means there is no null values in the dataset.

# %%
print("Checking if there is any duplicate values.")
df.duplicated().any()
# Out:
# Checking if there is any duplicate values.
# True

# %% [markdown]
# As we can see above the output is True, that means there exist duplicate values in data , then we have to remove it from code
# statement given below.

# %%
df.drop_duplicates(inplace = True) # inplace = True can make changes in original dataset

# %%
df.duplicated().any()
# Out:
# False

# %% [markdown]
# Now the output is false therefore we were able to successfully remove duplicate values from the dataset.

# %% [markdown]
# ## 2. Data Visualization

# %% [markdown]
# ### Correlation
# Correlation refers to the statistical relationship between the two variables/features. It measures the extent to which two variables are linearly related to eachother. For example, there is two variables study_time and marks of any student , if we look positive correlation between these two vairables students who spends more time in study their marks tend to increase. On the other hand in negative correlation the students who spend more time in study their marks tend to decrease.

# %%
correlation = df.corr() #corr() function gives the correaltion of all dataset
print('Lets see correaltion among all variable that the dataset contained.')
correlation
# Out:
# Lets see correaltion among all variable that the dataset contained.
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.094962 -0.063107  0.283121  0.207216  0.119492
# sex      -0.094962  1.000000 -0.051740 -0.057647 -0.195571  0.046022
# cp       -0.063107 -0.051740  1.000000  0.046486 -0.072682  0.096018
# trestbps  0.283121 -0.057647  0.046486  1.000000  0.125256  0.178125
# chol      0.207216 -0.195571 -0.072682  0.125256  1.000000  0.011428
# fbs       0.119492  0.046022  0.096018  0.178125  0.011428  1.000000
# restecg  -0.111590 -0.060351  0.041561 -0.115367 -0.147602 -0.083081
# thalach  -0.395235 -0.046439  0.293367 -0.048023 -0.005308 -0.007169
# exang     0.093216  0.143460 -0.392937  0.068526  0.064099  0.024729
# oldpeak   0.206040  0.098322 -0.146692  0.194600  0.050086  0.004514
# slope    -0.164124 -0.032990  0.116854 -0.122873  0.000417 -0.058654
# ca        0.302261  0.113060 -0.195356  0.099248  0.086878  0.144935
# ...

# %%
plt.figure(figsize = (20,5))
sns.heatmap(correlation, annot = True) # annot adds numbers on heatmap to make analysis more easier
# Out:
# <AxesSubplot:>

# %% [markdown]
# A correlation heatmap is a graphical tool that displays the correlation between multiple variables as a color-coded matrix.
# The color of each cell represents the strength and direction of the correlation, with less darker colors indicating stronger correlations.
# According to visualization above,
# 1. Negative correlations (when one variable increases, the other variable tends to decrease) indicates darker color like black for example:- age and thalach (maximum heart rate achived) with the number -0.4 .
# 2. Positive correlations (when one variable increases, the other variable tends to increase) indicates less darker color for example ( age and age varaible has positive correaltion or target(chances of heart attack) and chest pain has postive correlation in number 0.43)

# %% [markdown]
# ### Visualizing the male and female who has heart disease.

# %%
plt.figure(figsize = (8,5))  # figure size 
sns.countplot(x = 'sex', data = df , hue = 'target') #hue adds addtional column
plt.xticks([0,1],['Female','Male'])                  #xticks displays custom labels instead of the default numeric values.
plt.show()

# %% [markdown]
# Observation - According to the visual Female gender has high chances of heart attack than Male gender.

# %% [markdown]
# ### Age Variable Distribution

# %%
df['age'].min() #checking the minimum age exist in dataset
# Out:
# 29

# %%
df['age'].max() #checking the maximum age exist in dataset
# Out:
# 77

# %%
sns.displot(df['age'],bins=[20,25,30,35,40,45,50,55,60,65,70,75,80,85],kde = True)
# bins is using for grouping th data like in first bin there is age group 20 to 25, likewise in 2nd bin 30 to 35 age group
#kde is a way to estimate the probability density function
plt.show()

# %% [markdown]
# Observation - According to the figure above most of the heart patients are the age group of 50 - 60 and average age of heart patients is 54. The youngest is at 29 and the oldest is at 77.

# %% [markdown]
# ### Chest pain distribution according to target variable

# %%
plt.figure(figsize = (10,5))
sns.countplot(x = 'cp', data = df , hue = 'target')
plt.xticks([0,1,2,3],['typical angina','atypical angina','non-angina pain','asymptomatic'])
plt.show()

# %% [markdown]
# Observing Figure above it can be noticed that, most of the patients that experience chest pain has the less chances of heart attack. Most of the patients on the dataset has typical agnina stage and least number of patients are in asymtomatic stage. In the other other hand, non-angina pain stage patients has highest chances of heart attack.

# %% [markdown]
# ###  Fasting blood sugar distribution according to target variable

# %%
df['fbs'].value_counts()
# Out:
# 0    257
# 1     45
# Name: fbs, dtype: int64

# %%
plt.figure(figsize = (5,3))
sns.countplot(x = 'fbs' , data = df, hue = 'target')
plt.xticks([0,1],['False','True'])
plt.show()

# %% [markdown]
# By observing the above graph we can notice that the most of patients in dataset has fasting bloood sugar less than 120 mg/dl and we can assume that they have the most chances of heart attack.

# %% [markdown]
# ###  Resting blood pressure variable distribution

# %%
df['trestbps'].min() #checking lowest value of respective column
# Out:
# 94

# %%
df['trestbps'].max() #checking highest value of respective column
# Out:
# 200

# %%
sns.displot(df['trestbps'], bins = [90,100,110,120,130,140,150,160,170,180,190,200],kde = True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# As we can see in the figure above that the most patients has resting blood pressure  120 - 140 mmhg. Least restting blood pressue is 94 mmhg and highest resting blood pressure is 200 mmhg.

# %% [markdown]
# ### Comparing resting blood pressure as per sex variable

# %%
plt.figure(figsize = (10,5))
sns.countplot( x = 'trestbps', data = df , hue = 'sex' )
plt.xticks(rotation = 75) # rotates the number which makes more visible and helpful to analyze
plt.show()

# %%
g = sns.FacetGrid(df, hue ='sex', aspect = 4 ,palette=['blue','red']) #aspect is ration of subplot
# facetgrid is for visualizing the relationships between multiple variables specially for comparing 
g.map(sns.kdeplot,'trestbps',fill = True) # Mapping of the data is done by using kdeplot 
plt.legend(labels = ['Female','Male'])

# %% [markdown]
# Observation - By looking the both above figure we can say that most the male gender has 120 mmhg , 130 mmhg and 140 mmhg resting blood pressure.As we all know Female are less in number as compare to Male, therefore most of the Female has 130 mmhg resting blood pressure.

# %% [markdown]
# ###  Serum cholestoral variable distribution

# %%
df['chol'].min() # checking minimum value of the variable
# Out:
# 126

# %%
df['chol'].max() # checking maximum value of the variable
# Out:
# 564

# %%
df['chol'].hist()
print('Displaying the distribution in the histogram')
# Out:
# Displaying the distribution in the histogram

# %% [markdown]
# Observation - serum cholestoral in mg/dl As per the visual, We can say that the most of patients serum cholestoral is in between
# 240 - 250 mg/dl. Least and highest serum cholestoral is 126 and 564 respectively.

# %%
sns.displot(df['chol'], bins = [120,140,160,180,200,220,240,260,280,300,320,340,360,380,400,420,440,460,480,500,520,540,560,580],kde = True)
plt.show()

# %%
sns.displot(df['chol'], kind = 'kde')
plt.show()

# %% [markdown]
# Difference between the above two displot:-
# 1. The first approach bins assigned and creates a histogram with user defined bins with the kde plot at the top.
# 2. The second approach (kind='kde') directly creates a KDE plot without displaying a histogram.
# 3. The first approach gives more control over the binning of the data, while the second approach provides probable data distribution without user define boundries or groups.

# %% [markdown]
# # Conclusion

# %% [markdown]
# Due to the lack of health and awareness peoples getting disease like heart disease, right now it's the global issue. Through the data visualization and analysis of the features we've found some key feautures that direclty affects the heart disease.
#
# Chest pain, particularly atypical angina, is a symptom associated with heart disease. Regardless of the type of chest pain experienced, seeking medical attention is crucial.
#
# Monitoring resting blood pressure is essential, aiming for levels below 120mmHg. Exceeding 150mmHg, poses a considerable risk of heart disease.
#
# Annual check-ups are vital, as certain risk factors require professional attention. Additionally, as age increases, there can be more things that might not be as healthy, so it's really important to take care of ourselves and stay ahead of any problems.
