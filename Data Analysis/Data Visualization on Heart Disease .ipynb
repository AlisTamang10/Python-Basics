# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('heart.csv')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.describe(include = 'all')
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
df.shape
# Out:
# (1025, 14)

# %%
df.isnull()
# Out:
#         age    sex     cp  trestbps   chol    fbs  restecg  thalach  exang  \
# 0     False  False  False     False  False  False    False    False  False
# 1     False  False  False     False  False  False    False    False  False
# 2     False  False  False     False  False  False    False    False  False
# 3     False  False  False     False  False  False    False    False  False
# 4     False  False  False     False  False  False    False    False  False
# ...     ...    ...    ...       ...    ...    ...      ...      ...    ...
# 1020  False  False  False     False  False  False    False    False  False
# 1021  False  False  False     False  False  False    False    False  False
# 1022  False  False  False     False  False  False    False    False  False
# 1023  False  False  False     False  False  False    False    False  False
# 1024  False  False  False     False  False  False    False    False  False
#
#       oldpeak  slope     ca   thal  target
# ...

# %%
df.isnull().any()
# Out:
# age         False
# sex         False
# cp          False
# trestbps    False
# chol        False
# fbs         False
# restecg     False
# thalach     False
# exang       False
# oldpeak     False
# slope       False
# ca          False
# thal        False
# target      False
# dtype: bool

# %%
df.duplicated().any()
# Out:
# True

# %%
df.drop_duplicates(inplace = True)

# %%
df.duplicated().any()
# Out:
# False

# %%
df.shape
# Out:
# (302, 14)

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
#positive corealation 
#negative corelation 
#no co-realtion 
corr = df.corr()

# %%
plt.figure(figsize = (20,5))
sns.heatmap(corr,annot = True)
#heatmap show the value on the basis of intensity
# Out:
# <AxesSubplot:>

# %%
df['target'].value_counts()
# Out:
# 1    164
# 0    138
# Name: target, dtype: int64

# %%
plt.figure(figsize = (2,3))
sns.countplot(x = 'target', data = df )
# Out:
# <AxesSubplot:xlabel='target', ylabel='count'>

# %%
df['sex'].value_counts()
# Out:
# 1    206
# 0     96
# Name: sex, dtype: int64

# %%
plt.figure(figsize = (2,3))
sns.countplot(x = df['sex'], data = df )
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
# plt.figure(figsize = (2,3))
# x = ['Female','Male']
# y = [0,1]
# sns.barplot(x, y , data = df)
# plt.show()

# %%
plt.figure(figsize = (2,3))
sns.countplot(x = df['sex'])
plt.xticks([0,1],['Female','Male'])
plt.show()

# %%
#gender distribution according to target
plt.figure(figsize = (2,3))
sns.countplot(x = 'sex', data = df , hue = 'target')
plt.xticks([0,1],['Female','Male'])
plt.show()

#hue adds addtional columns

# %%
df['age'].value_counts()
# Out:
# 58    19
# 57    17
# 54    16
# 59    14
# 52    13
# 51    12
# 44    11
# 60    11
# 56    11
# 62    11
# 41    10
# 64    10
# 67     9
# 63     9
# 42     8
# 43     8
# 65     8
# 53     8
# 61     8
# 45     8
# 55     8
# 50     7
# 46     7
# 66     7
# 48     7
# 49     5
# 47     5
# 68     4
# 70     4
# 35     4
# 39     4
# 69     3
# 40     3
# 71     3
# 37     2
# 38     2
# 34     2
# 76     1
# 29     1
# 77     1
# 74     1
# Name: age, dtype: int64

# %%
sns.displot(df['age'],bins=[20,25,30,35,40,45,50,55,60,65,70,75,80,85],kde = True)
plt.show()

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 2     70    1   0       145   174    0        1      125      1      2.6
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 723   68    0   2       120   211    0        0      115      0      1.5
# 733   44    0   2       108   141    0        1      175      0      0.6
# 739   52    1   0       128   255    0        1      161      1      0.0
# 843   59    1   3       160   273    0        0      125      0      0.0
# 878   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# ...

# %%
df['cp'].value_counts()
# Out:
# 0    143
# 2     86
# 1     50
# 3     23
# Name: cp, dtype: int64

# %%
typesofcp=df["cp"].unique()
numbersofcp=df["cp"].value_counts()
typesofcp
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
numbersofcp
# Out:
# 0    143
# 2     86
# 1     50
# 3     23
# Name: cp, dtype: int64

# %%
sns.barplot(x = typesofcp , y = numbersofcp , data = df)
plt.xlabel('types of chest pain')
plt.ylabel('people with chest pain')
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.countplot(x = 'cp', data = df , hue = 'target')
plt.xticks([0,1,2,3],['typical angina','atypical angina','non-angina pain','asymptomatic'])
plt.show()

# %%
#bloods group distribution 
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 2     70    1   0       145   174    0        1      125      1      2.6
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 723   68    0   2       120   211    0        0      115      0      1.5
# 733   44    0   2       108   141    0        1      175      0      0.6
# 739   52    1   0       128   255    0        1      161      1      0.0
# 843   59    1   3       160   273    0        0      125      0      0.0
# 878   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# ...

# %%
df['fbs'].value_counts()
# Out:
# 0    257
# 1     45
# Name: fbs, dtype: int64

# %%
plt.figure(figsize = (5,3))
sns.countplot(x = 'fbs' , data = df, hue = 'target')
plt.xticks([0,1],['False','True'])
plt.show()

# %%
#check resting blood sugar distribution 
df['trestbps'].value_counts()
# Out:
# 120    37
# 130    36
# 140    32
# 110    19
# 150    17
# 138    12
# 128    12
# 125    11
# 160    11
# 112     9
# 132     8
# 118     7
# 135     6
# 108     6
# 124     6
# 152     5
# 134     5
# 145     5
# 122     4
# 100     4
# 170     4
# 115     3
# 136     3
# 180     3
# 126     3
# 142     3
# 105     3
# 144     2
# 102     2
# 94      2
# 146     2
# 178     2
# 148     2
# 174     1
# 165     1
# 156     1
# 164     1
# 172     1
# 155     1
# 114     1
# 200     1
# 154     1
# 106     1
# 104     1
# 192     1
# 129     1
# 117     1
# 123     1
# 101     1
# Name: trestbps, dtype: int64

# %%
#sns.displot(df['age'],bins=[20,25,30,35,40,45,50,55,60,65,70,75,80,85],kde = True)
df['trestbps'].min()
# Out:
# 94

# %%
df['trestbps'].max()
# Out:
# 200

# %%
sns.displot(df['trestbps'], bins = [90,100,110,120,130,140,150,160,170,180,190,200],kde = True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#compare resting blood pressure as per sex columns
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df['restecg'].value_counts()
# Out:
# 1    151
# 0    147
# 2      4
# Name: restecg, dtype: int64

# %%
plt.figure(figsize = (10,5))
sns.countplot( x = 'trestbps', data = df , hue = 'sex' )
# plt.figure(figsize = (10,5))
# sns.countplot(x = 'cp', data = df , hue = 'target')
# plt.xticks([0,1,2,3],['typical angina','atypical angina','non-angina pain','asymptomatic'])
# plt.show()
plt.xticks(rotation = 75)
plt.show()

# %%
# variable distribution , multiple variable distribution 
g = sns.FacetGrid(df, hue ='sex', aspect = 4 ,palette=['red','blue'])
g.map(sns.kdeplot,'trestbps',fill = True) #Mapping of the data is done by using kdeplot 
plt.legend(labels = ['Male','Female'])
#when you want to visualize the ditribution of a variabe or the relationship betwwn multiple varibales separately

# %%
# serum colestarial 
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df['chol'].value_counts()
# Out:
# 204    6
# 197    6
# 234    6
# 212    5
# 254    5
#       ..
# 182    1
# 417    1
# 186    1
# 126    1
# 141    1
# Name: chol, Length: 152, dtype: int64

# %%
df['chol'].min()
# Out:
# 126

# %%
df['chol'].max()
# Out:
# 564

# %%
df['chol'].hist()
# Out:
# <AxesSubplot:>

# %%
sns.displot(df['chol'], bins = [120,140,160,180,200,220,240,260,280,300,320,340,360,380,400,420,440,460,480,500,520,540,560,580],kde = True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.displot(df['chol'], kind = 'kde')
plt.show()

# %%
#sns.barplot()
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
plt.figure(figsize = (8,5))
sns.barplot( x = 'cp' , y = 'target' , data = df)
plt.xticks(rotation = 75)
plt.show()

# %%
gen_count = df['sex'].value_counts()
plt.figure(figsize=(8,8))
plt.pie(gen_count,labels =['Male','Female'], autopct='%1.1f%%',startangle = 130, colors = ['red','blue'])
plt.title('Distrubution of gender')
# Out:
# Text(0.5, 1.0, 'Distrubution of gender')

# %%
chest_pain = df['cp'].value_counts()
chest_pain
# Out:
# 0    143
# 2     86
# 1     50
# 3     23
# Name: cp, dtype: int64

# %%
plt.figure(figsize=(8,8))
plt.pie(chest_pain , labels = chest_pain.index, autopct = '%1.1f%%',startangle = 90 )
plt.title("Ditsribution of chest pain")
# Out:
# Text(0.5, 1.0, 'Ditsribution of chest pain')

# %%
#boxplot 
plt.figure(figsize =(8,8))
sns.boxplot(x = 'cp', y ='thalach' , data = df)
plt.title('Box plot of maximum heart rate by chest pain')
# Out:
# Text(0.5, 1.0, 'Box plot of maximum heart rate by chest pain')

# %%
#boxplot 
plt.figure(figsize =(8,8))
sns.lineplot(x = 'age', y ='thalach' , data = df, ci = None)
plt.title('Box plot of maximum heart rate by chest pain')
# Out:
# Text(0.5, 1.0, 'Box plot of maximum heart rate by chest pain')

# %%
# plt.figure(figsize = (8,7))
# plt.lineplot(x = 'age', y = '')
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
plt.figure(figsize = (8,7))
sns.lineplot(x ='age', y = 'trestbps' , data = df, ci = None)
# Out:
# <AxesSubplot:xlabel='age', ylabel='trestbps'>

# %%
plt.figure(figsize = (8,7))
sns.scatterplot(x ='age', y = 'thalach', data = df ,alpha = 1)
plt.title('Scatter plot of thalach by age')
# Out:
# Text(0.5, 1.0, 'Scatter plot of thalach by age')
